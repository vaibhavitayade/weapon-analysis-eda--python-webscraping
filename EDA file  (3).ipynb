# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\91982\Downloads\weaponsdataaa (4).xls")
df
# Out:
#              Name  Price Weight Length (cm)   Size   Caliber Range  \
# 0        SMG M611   $336  6.7kg        45cm   52cm   .45 ACP  415m
# 1    Shotgun M362  $1334  3.9kg        42cm  112cm       9mm  744m
# 2     Sniper M860   $920  6.7kg        86cm   69cm    5.56mm  313m
# 3        SMG M209  $2302  3.0kg        43cm   62cm    7.62mm  114m
# 4    Shotgun M796   $819  7.0kg        93cm   90cm       9mm  496m
# ..            ...    ...    ...         ...    ...       ...   ...
# 395  Shotgun M493  $1795  4.9kg        49cm   43cm  12 Gauge  306m
# 396   Pistol M940  $2500  7.9kg        52cm   96cm    5.56mm  290m
# 397    Rifle M438  $1249  7.2kg        44cm   91cm    7.62mm  689m
# 398   Pistol M731  $1970  7.7kg        98cm  103cm       9mm  515m
# 399   Sniper M717  $2017  5.1kg        80cm   47cm       9mm  117m
#
#             Stock            Brand      FPS Magazine Capacity Power Source  \
# 0    Out of Stock              G&G  253 FPS        158 rounds       Spring
# ...

# %%
df.head()
# Out:
#            Name  Price Weight Length (cm)   Size  Caliber Range         Stock  \
# 0      SMG M611   $336  6.7kg        45cm   52cm  .45 ACP  415m  Out of Stock
# 1  Shotgun M362  $1334  3.9kg        42cm  112cm      9mm  744m      In Stock
# 2   Sniper M860   $920  6.7kg        86cm   69cm   5.56mm  313m  Out of Stock
# 3      SMG M209  $2302  3.0kg        43cm   62cm   7.62mm  114m      In Stock
# 4  Shotgun M796   $819  7.0kg        93cm   90cm      9mm  496m      In Stock
#
#          Brand      FPS Magazine Capacity Power Source  Customer Rating
# 0          G&G  253 FPS        158 rounds       Spring              2.8
# 1         CYMA  338 FPS        121 rounds          Gas              4.2
# 2         CYMA  420 FPS        194 rounds          CO2              1.9
# 3          G&G  386 FPS        191 rounds          CO2              1.4
# 4  Tokyo Marui  307 FPS         49 rounds     Electric              3.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               400 non-null    object
#  1   Price              400 non-null    object
#  2   Weight             400 non-null    object
#  3   Length (cm)        400 non-null    object
#  4   Size               400 non-null    object
#  5   Caliber            400 non-null    object
#  6   Range              400 non-null    object
#  7   Stock              400 non-null    object
#  8   Brand              400 non-null    object
#  9   FPS                400 non-null    object
#  10  Magazine Capacity  400 non-null    object
#  11  Power Source       400 non-null    object
#  12  Customer Rating    400 non-null    float64
# dtypes: float64(1), object(12)
# memory usage: 40.8+ KB

# %% [markdown]
# ### Checking the description of the data:

# %%
df.describe()
# Out:
#        Customer Rating
# count       400.000000
# mean          3.035500
# std           1.184947
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.125000
# max           5.000000

# %%
df.describe(include = 'object')
# Out:
#               Name  Price Weight Length (cm)  Size Caliber Range     Stock  \
# count          400    400    400         400   400     400   400       400
# unique         390    364     64          81    80       5   309         2
# top     Rifle M323  $1675  2.5kg        41cm  76cm     9mm  369m  In Stock
# freq             2      3     14          13    11      97     4       201
#
#        Brand      FPS Magazine Capacity Power Source
# count    400      400               400          400
# unique     4      180               158            4
# top      G&G  253 FPS        133 rounds       Spring
# freq     111        6                 6          105

# %%
df['Cost'] = df['Cost'].astype(float)
df['Cost']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cost'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['Cost'] = df['Cost'].astype(float)
#       2 df['Cost']
#
# ...

# %%
df.duplicated().sum()

# %%
df.duplicated()

# %%
df.drop_duplicates()

# %%
df.drop_duplicates(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               400 non-null    object
#  1   Price              400 non-null    object
#  2   Weight             400 non-null    object
#  3   Length (cm)        400 non-null    object
#  4   Size               400 non-null    object
#  5   Caliber            400 non-null    object
#  6   Range              400 non-null    object
#  7   Stock              400 non-null    object
#  8   Brand              400 non-null    object
#  9   FPS                400 non-null    object
#  10  Magazine Capacity  400 non-null    object
#  11  Power Source       400 non-null    object
#  12  Customer Rating    400 non-null    float64
# dtypes: float64(1), object(12)
# memory usage: 40.8+ KB

# %%
df.columns
# Out:
# Index(['Name', 'Price', 'Weight', 'Length (cm)', 'Size', 'Caliber', 'Range',
#        'Stock', 'Brand', 'FPS', 'Magazine Capacity', 'Power Source',
#        'Customer Rating'],
#       dtype='object')

# %%
df['Weapon Name'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weapon Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df['Weapon Name'].unique()
#
# ...

# %%
df['Category'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['Category'].unique()
#
# ...

# %%
df['Cost'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cost'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['Cost'].unique()
#
# ...

# %% [markdown]
# # Visualization:
# - We are going to visualize the data in to two formats or in two types that are:

# %% [markdown]
# ## Univariate Analysis

# %%
colors = sns.color_palette("viridis", n_colors=len(df.select_dtypes(include="number").columns))

for i, col in enumerate(df.select_dtypes(include="number").columns):
    plt.figure(figsize=(7,4))
    sns.histplot(
        data=df, 
        x=col, 
        bins=20, 
        kde=True, 
        color=colors[i] 
    )
    plt.title(f"Histogram of {col}", fontsize=14)
    plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(df['Cost'], bins=20, kde=True)
plt.title("Distribution of Price")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cost'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 plt.figure(figsize=(7,5))
# ...

# %% [markdown]
# ## Stock status

# %%
sns.countplot(data=df, x="Stock", palette="coolwarm")
plt.title("Stock Availability")
plt.show()
# Out:
# C:\Users\91982\AppData\Local\Temp\ipykernel_52528\3850696198.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Stock", palette="coolwarm")

# %%
sns.countplot(data=df, x="Caliber", palette="Set2")
plt.title("Weapons by Caliber")
plt.show()
# Out:
# C:\Users\91982\AppData\Local\Temp\ipykernel_52528\2873700639.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Caliber", palette="Set2")

# %% [markdown]
# ## Observation
#
# - Most numerical features (like Cost) are right-skewed, indicating that the majority of weapons fall in the lower range with only a few very high-value outliers.
#
# - Features such as Range and Weight show wider variability, suggesting distinct groups of weapons and highlighting performance differences across categories.

# %%
plt.figure(figsize=(8,5))
sns.countplot(
    data=df,
    x="Category", 
    order=df["Category"].value_counts().index,  
    hue="Category",                             
    palette="viridis",
    legend=False
)
plt.xticks(rotation=45)
plt.title("Count of Weapons by Category", fontsize=16)
plt.show()

# %% [markdown]
# ## Observations
#
# - The distribution shows that certain categories (e.g., [highest bar’s category]) dominate the dataset, indicating they are the most common weapon types.
#
# - Some categories appear much less frequently, highlighting imbalance in representation across weapon categories.

# %%
df['Caliber'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6,6), startangle=140)
plt.title("Weapon Caliber Distribution")
plt.ylabel("")
plt.show()

# %%
sns.countplot(data=df, x=col, order=df[col].value_counts().index, color="orange")
# Out:
# <Axes: xlabel='Range (m)', ylabel='count'>

# %% [markdown]
# ## Bivariate

# %%
top_n = 20

plt.figure(figsize=(10,8))
sns.barplot(
    y=df["Weapon Name"].value_counts().head(top_n).index,
    x=df["Weapon Name"].value_counts().head(top_n).values,
    palette="viridis"
)
plt.title(f"Top {top_n} Weapons by Count", fontsize=16)
plt.xlabel("Count")
plt.ylabel("Weapon Name")
plt.show()
# Out:
# C:\Users\91982\AppData\Local\Temp\ipykernel_52528\15912637.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## Observations
#
# - A few weapons dominate the dataset, with the top-ranked weapon appearing far more frequently than others, indicating its popularity or higher availability.
#
# - The frequency drops gradually for the remaining weapons, showing a long-tail distribution where most weapons appear relatively less often.

# %%
plt.figure(figsize=(7,5))
sns.histplot(df['Cost'], bins=20, kde=True)
plt.title("Distribution of Weapon Cost")
plt.xlabel("Cost")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(df['Weight (kg)'], bins=15, kde=True, color="green")
plt.title("Distribution of Weapon Weight")
plt.xlabel("Weight (kg)")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(df['Range (m)'], bins=20, kde=True, color="orange")
plt.title("Distribution of Weapon Range")
plt.xlabel("Range (m)")
plt.show()

# %%
  plt.figure(figsize=(8,5))
sns.countplot(
    data=df,
    x="Category", 
    order=df["Category"].value_counts().index,  
    hue="Category",                             
    palette="viridis",
    legend=False
)
plt.xticks(rotation=45)
plt.title("Count of Weapons by Category", fontsize=16)
plt.show()

# %% [markdown]
# ## Observations
#
# - The dataset is dominated by a few categories (the tallest bars), showing that those weapon types are much more common compared to others.
#
# - Several categories have very low counts, indicating they are rare or underrepresented in the dataset.

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    x = weapon counts.head(10).values,
    y = weapon counts.head(10).index,
    palette="coolwarm"
)
plt.title("Top 10 Most Selling Weapons", fontsize=16)
plt.xlabel("Number of Sales")
plt.ylabel("Weapon Name")
plt.show()
# Out:
#   Cell In[27], line 3
#     x = weapon counts.head(10).values,
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
weapon_counts = df["Weapon Name"].value_counts()

plt.figure(figsize=(10,6))
sns.barplot(
    x=weapon_counts.head(10).values,
    y=weapon_counts.head(10).index,
    palette="coolwarm"
)
plt.title("Top 10 Most Selling Weapons", fontsize=16)
plt.xlabel("Number of Sales")
plt.ylabel("Weapon Name")
plt.show()
# Out:
# C:\Users\91982\AppData\Local\Temp\ipykernel_52528\3491615624.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
costs = df['Cost'].value_counts()

# %%
df['Caliber'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Caliber'].skew()
# Out:
# 0.9411382877986166

# %%
sns.histplot(data=df, x='Cost', bins=20, edgecolor="black",
             color=sns.color_palette("viridis")[3])
# Out:
# <Axes: xlabel='Cost', ylabel='Count'>

# %%
df['Weapon Name'].head()
# Out:
# 0        SMG M841
# 1     Pistol M734
# 2      Rifle M457
# 3    Shotgun M179
# 4     Sniper M670
# Name: Weapon Name, dtype: object

# %%
import re
regex = r'^\w+'
df['Brand'] = df['Weapon Name'].apply(lambda x : re.findall(regex,x))
df.head()
# Out:
#     Weapon Name        Category      Cost  Weight (kg)  Caliber  Range (m)  \
# 0      SMG M841  Submachine Gun  109726.0          2.2    18.53      614.0
# 1   Pistol M734         Handgun   47393.0          2.5     7.62      389.0
# 2    Rifle M457           Rifle  191066.0          4.6    18.53      639.0
# 3  Shotgun M179         Shotgun  167826.0          6.2     7.62       85.0
# 4   Sniper M670          Sniper  172308.0          6.0    11.43      562.0
#
#           Stock      Brand
# 0  Out of Stock      [SMG]
# 1  Out of Stock   [Pistol]
# 2      In Stock    [Rifle]
# 3      In Stock  [Shotgun]
# 4      In Stock   [Sniper]

# %%
df['Brand'] = df['Brand'].apply(lambda x :''.join(x))
df.head()
# Out:
#     Weapon Name        Category      Cost  Weight (kg)  Caliber  Range (m)  \
# 0      SMG M841  Submachine Gun  109726.0          2.2    18.53      614.0
# 1   Pistol M734         Handgun   47393.0          2.5     7.62      389.0
# 2    Rifle M457           Rifle  191066.0          4.6    18.53      639.0
# 3  Shotgun M179         Shotgun  167826.0          6.2     7.62       85.0
# 4   Sniper M670          Sniper  172308.0          6.0    11.43      562.0
#
#           Stock    Brand
# 0  Out of Stock      SMG
# 1  Out of Stock   Pistol
# 2      In Stock    Rifle
# 3      In Stock  Shotgun
# 4      In Stock   Sniper

# %%
brand_order = df['Brand'].value_counts().index 
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Brand", order= brand_order, palette="Set2")
plt.xticks(rotation=45, ha = "right")
plt.title("Brand Distribution (Sorted)", fontsize=14, fontweight="bold")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda1\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 brand_order = df['Brand'].value_counts().index
# ...

# %%
report = df.groupby(by = 'Brand')['Cost'].agg(['min','max','mean'])
report
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 report = df.groupby(by = 'Brand')['Cost'].agg(['min','max','mean'])
#       2 report
#
# File ~\anaconda1\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
plt.figure(figsize=(8,5))
report['max'].plot(
    kind='barh', 
    color=sns.color_palette("viridis", len(report['max'])), 
    edgecolor="black"
)

plt.title("Max Values (Horizontal)", fontsize=14, fontweight="bold")
plt.xlabel("Max")
plt.ylabel("Index")
plt.show()

# %%
plt.figure(figsize=(12,4))
sns.violinplot(x='Brand', y='Cost', data=df, palette="husl")
plt.xticks(rotation=45, ha="right")
plt.title("Cost Distribution by Brand (Violin Plot)", fontsize=14, fontweight="bold")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x='Range (m)', y='Cost', data=df, hue='Cost', palette="viridis", s=80, edgecolor="black")
plt.title("Range vs Cost (Gradient by Cost)", fontsize=14, fontweight="bold")
plt.show()

# %%
sns.regplot(x='Range (m)', y='Cost', data=df, scatter_kws={'color':'pink'}, line_kws={'color':'lightgreen'})
plt.show()

# %%
df[['Range (m)', 'Cost']].corr()
# Out:
#            Range (m)      Cost
# Range (m)   1.000000  0.007811
# Cost        0.007811  1.000000

# %% [markdown]
# ## Bivariate

# %%
sns.heatmap(df[['Range (m)','Cost']].corr(),annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(7,5))
sns.countplot(x='Caliber', data=df, palette="Set3")
plt.title("Count of Weapons by Caliber")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\91982\AppData\Local\Temp\ipykernel_38168\3813095454.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Caliber', data=df, palette="Set3")

# %%
plt.figure(figsize=(7,5))
sns.histplot(df['Stock'], bins=15, kde=True, color="red")
plt.title("Distribution of Stock Levels")
plt.xlabel("Stock")
plt.show()

# %% [markdown]
# ## Multivariate Pairplot

# %%
if 'Category' in df.columns:
    sns.pairplot(df, hue='Category', palette='viridis', diag_kind='kde')
else:
    sns.pairplot(df, diag_kind='kde', palette='viridis')

plt.suptitle("Pairplot of Dataset", fontsize=16, y=1.02)
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="Blues", linewidths=0.5)

plt.title("Correlation Heatmap", fontsize=14, fontweight="bold")
plt.show()

# %%
df.columns
# Out:
# Index(['Weapon Name', 'Category', 'Cost', 'Weight (kg)', 'Caliber',
#        'Range (m)', 'Stock'],
#       dtype='object')

# %%
plt.style.use("dark_background")

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df,
    x="Cost",
    y="Cost",        # (or another numeric if available)
    hue="Weapon Name",      # categorical column
    palette="tab10"
)
plt.title("Multivariate Scatterplot", fontsize=14, fontweight="bold")
plt.show()

# %%
plt.style.use("dark_background")
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df,
    x="Cost",       # replace with your numeric column
    y="Caliber",       # replace with your numeric column
    hue="Category",  # replace with your categorical column
    palette="tab10"
)
plt.title("Multivariate Scatterplot", fontsize=14, fontweight="bold")
plt.show()

# %%
df.hist(figsize=(12, 8), bins=20, edgecolor='black')
plt.suptitle("Histograms of Numerical Features")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("weaponsdataaa.csv")

# Pie chart of Stock availability
df['Stock'].value_counts().plot(
    kind='pie', 
    autopct='%1.1f%%', 
    figsize=(6,6),
    colors=['#66b3ff','#ff9999'],
    startangle=90,
    shadow=True
)

plt.title("Stock Availability of Weapons")
plt.ylabel("")  # Remove y-label for pie chart
plt.show()

# %%
sns.pairplot(df[['Cost','Weight (kg)','Range (m)','Stock']], diag_kind='kde')
plt.suptitle("Pairplot of Numeric Features", y=1.02)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x="Cost", y="Range (m)", hue="Category", data=df, palette="Set1")
plt.title("Cost vs Range by Category")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x="Cost", y="Range (m)", size="Weight (kg)", hue="Category", data=df, sizes=(20,200))
plt.title("Cost vs Range with Weight size and Category hue")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Category", y="Cost", hue="Caliber", data=df)
plt.title("Cost Distribution by Category & Caliber")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[['Cost','Weight (kg)','Range (m)','Stock']].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 plt.figure(figsize=(8,6))
# ----> 2 sns.heatmap(df[['Cost','Weight (kg)','Range (m)','Stock']].corr(), annot=True, cmap="coolwarm", fmt=".2f")
#       3 plt.title("Correlation Heatmap")
#       4 plt.show()
#
# File ~\anaconda1\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda1\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Cost'], df['Weight (kg)'], df['Range (m)'], c=df['Stock'], cmap="viridis", s=50)
ax.set_xlabel("Cost")
ax.set_ylabel("Weight (kg)")
ax.set_zlabel("Range (m)")
plt.title("3D Scatterplot: Cost vs Weight vs Range (color=Stock)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda1\Lib\site-packages\matplotlib\axes\_axes.py:4618, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4617 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4618     colors = mcolors.to_rgba_array(c)
#    4619 except (TypeError, ValueError) as err:
#
# File ~\anaconda1\Lib\site-packages\matplotlib\colors.py:512, in to_rgba_array(c, alpha)
#     511 else:
# --> 512     rgba = np.array([to_rgba(cc) for cc in c])
#     514 if alpha is not None:
#
# File ~\anaconda1\Lib\site-packages\matplotlib\colors.py:314, in to_rgba(c, alpha)
#     313 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 314     rgba = _to_rgba_no_colorcycle(c, alpha)
#     315     try:
#
# ...

# %%
df.columns

# %%
sns.heatmap(data = df , x = 'Weapon Name' , y = 'Stock')

# %%
df['Stock'].unique()

# %%
def cat_cat(df , col1 , col2 , head = 10):
    # Create a contingency table (cross-tabulation)
    contingency_table = pd.crosstab(df[col1], df[col2])
    
    top_values = contingency_table.sum(axis=1).nlargest(head).index
    contingency_table = contingency_table.loc[top_values]
    
    contingency_table_percent = contingency_table.div(contingency_table.sum(axis=1), axis=0) * 100 # Convert contingency table to percentages
    print(contingency_table_percent)

    plt.figure(figsize = (15,6))

    # Bar plot
    # plt.subplot(1,2,1)
    # sns.barplot(data = contingency_table_percent.T , orient = 'h')
    # plt.title(f'Top {head} categories in {col1} vs {col2}')
    # plt.xlabel('Percentage')
    # plt.ylabel(col1)

    #Heat Map
    plt.subplot(1,2,2)
    sns.heatmap(contingency_table_percent , annot = True , fmt = '.2f' , cmap = 'coolwarm' , cbar_kws = {'label' : 'Percentage'})
    plt.xlabel(f'{col2}')
    plt.ylabel(f'{col1}')
    plt.title(f'Heatmap of {col1} vs {col2}')
    plt.show()

# %%
cat_cat(df , 'Weapon Name' , 'Stock')

# %%
cat_cat(df , 'Category' , 'Stock')
